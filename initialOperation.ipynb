# %%
#ESERCITAZIONE MONGO DB

import pymongo
import pandas

# %%
#stringa di connessione
client = pymongo.MongoClient(
    "mongodb+srv://Zane:E0ijrCeYF0724awa@cluster0.cdyyu.mongodb.net/esercizi?retryWrites=true&w=majority&ssl=true&ssl_cert_reqs=CERT_NONE")
db = client["sample_airbnb"] #equivalente a db = client.sample_restaurants.restaurants
#collection = db["restaurants"]

# %%
doc = db.listingsAndReviews.find_one()
doc
# Out:
# {'_id': '10006546',
#  'listing_url': 'https://www.airbnb.com/rooms/10006546',
#  'name': 'Ribeira Charming Duplex',
#  'summary': 'Fantastic duplex apartment with three bedrooms, located in the historic area of Porto, Ribeira (Cube) - UNESCO World Heritage Site. Centenary building fully rehabilitated, without losing their original character.',
# ...

# %%
df = pandas.DataFrame(list(db.listingsAndReviews.find()))
df.head(2)
# Out:
#         _id                            listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10009999  https://www.airbnb.com/rooms/10009999
#
#                            name  \
# 0       Ribeira Charming Duplex
# 1  Horto flat with small garden
#
#                                              summary  \
# 0  Fantastic duplex apartment with three bedrooms...
# 1  One bedroom + sofa-bed in quiet and bucolic ne...
#
#                                                space  \
# 0  Privileged views of the Douro River and Ribeir...
# 1  Lovely one bedroom + sofa-bed in the living ro...
#
#                                          description  \
# 0  Fantastic duplex apartment with three bedrooms...
# 1  One bedroom + sofa-bed in quiet and bucolic ne...
#
#                                neighborhood_overview  \
# 0  In the neighborhood of the river, you can find...
# 1  This charming ground floor flat is located in ...
#
# ...

# %%
df = pandas.DataFrame(list(db.listingsAndReviews.find()))
df.head(2)
# Out:
#         _id                            listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1  10009999  https://www.airbnb.com/rooms/10009999
#
#                            name  \
# 0       Ribeira Charming Duplex
# 1  Horto flat with small garden
#
#                                              summary  \
# 0  Fantastic duplex apartment with three bedrooms...
# 1  One bedroom + sofa-bed in quiet and bucolic ne...
#
#                                                space  \
# 0  Privileged views of the Douro River and Ribeir...
# 1  Lovely one bedroom + sofa-bed in the living ro...
#
#                                          description  \
# 0  Fantastic duplex apartment with three bedrooms...
# 1  One bedroom + sofa-bed in quiet and bucolic ne...
#
#                                neighborhood_overview  \
# 0  In the neighborhood of the river, you can find...
# 1  This charming ground floor flat is located in ...
#
# ...

# %%
# gli appartamenti che costano più di 100 $ a notte
agg = db.listingsAndReviews.find({"price" : {"$gt": 100}}).limit(5)
agg = pandas.DataFrame(list(agg))
agg
# Out:
#         _id                            listing_url  \
# 0  10009999  https://www.airbnb.com/rooms/10009999
# 1   1001265   https://www.airbnb.com/rooms/1001265
# 2  10030955  https://www.airbnb.com/rooms/10030955
# 3   1003530   https://www.airbnb.com/rooms/1003530
# 4  10038496  https://www.airbnb.com/rooms/10038496
#
#                                   name  \
# 0         Horto flat with small garden
# 1     Ocean View Waikiki Marina w/prkg
# 2          Apt Linda Vista Lagoa - Rio
# 3  New York City - Upper West Side Apt
# 4         Copacabana Apartment Posto 6
#
#                                              summary  \
# 0  One bedroom + sofa-bed in quiet and bucolic ne...
# 1  A short distance from Honolulu's billion dolla...
# 2  Quarto com vista para a Lagoa Rodrigo de Freit...
# 3
# 4  The Apartment has a living room, toilet, bedro...
#
#                                                space  \
# 0  Lovely one bedroom + sofa-bed in the living ro...
# ...

# %%
# gli appartamenti che costano tra i 100 $ e i 200 $ a notte
agg = db.listingsAndReviews.find({"price" : {"$gt": 100, "$lt": 200}}).limit(5)
agg = pandas.DataFrame(list(agg))
agg
# Out:
#         _id                            listing_url  \
# 0   1001265   https://www.airbnb.com/rooms/1001265
# 1   1003530   https://www.airbnb.com/rooms/1003530
# 2  10038496  https://www.airbnb.com/rooms/10038496
# 3  10066928  https://www.airbnb.com/rooms/10066928
# 4  10084023  https://www.airbnb.com/rooms/10084023
#
#                                   name  \
# 0     Ocean View Waikiki Marina w/prkg
# 1  New York City - Upper West Side Apt
# 2         Copacabana Apartment Posto 6
# 3       3 chambres au coeur du Plateau
# 4    City center private room with bed
#
#                                              summary  \
# 0  A short distance from Honolulu's billion dolla...
# 1
# 2  The Apartment has a living room, toilet, bedro...
# 3  Notre appartement comporte 3 chambres avec cha...
# 4  House is located 5mins walk from Sham Shui Po ...
#
#                                                space  \
# 0  Great studio located on Ala Moana across the s...
# ...

# %%
# gli appartamenti che hanno almeno 5 posti letto e che costano tra i 50 $ e 100 $ a notte
agg = db.listingsAndReviews.find({ "beds": {"$gt": 4},"price" : {"$gt": 50, "$lt": 100}}).limit(5)
agg = pandas.DataFrame(list(agg))
agg
# Out:
#         _id                            listing_url  \
# 0  10006546  https://www.airbnb.com/rooms/10006546
# 1   1111410   https://www.airbnb.com/rooms/1111410
# 2  11413023  https://www.airbnb.com/rooms/11413023
# 3  13372754  https://www.airbnb.com/rooms/13372754
# 4  13841305  https://www.airbnb.com/rooms/13841305
#
#                                   name  \
# 0              Ribeira Charming Duplex
# 1         MONTJUIC FOUNTAINS APARTMENT
# 2                      Lulapartment II
# 3                  Ohana House retreat
# 4  Oporto Charming Townhouse - ﾒﾄﾛ100m
#
#                                              summary  \
# 0  Fantastic duplex apartment with three bedrooms...
# 1  Excellent apartment situated opposite Barcelon...
# 2  Apartamento situado no centro histórico do Por...
# 3  Ohana House is close to nature and all green. ...
# 4  駐車場､庭(120m²)とT2(100㎡)｡ｳﾞｨﾗは､現在のすべての施設で､広々とした居心...
#
#                                                space  \
# ...

# %%
# gli appartamenti che non si trovano in Portogallo e in Spagna
agg = db.listingsAndReviews.find({ "address.country": {"$nin":["Portugal","Spain"]}}).limit(5)
agg = pandas.DataFrame(list(agg))
agg
# Out:
#         _id                            listing_url  \
# 0  10009999  https://www.airbnb.com/rooms/10009999
# 1   1001265   https://www.airbnb.com/rooms/1001265
# 2  10021707  https://www.airbnb.com/rooms/10021707
# 3  10030955  https://www.airbnb.com/rooms/10030955
# 4   1003530   https://www.airbnb.com/rooms/1003530
#
#                                   name  \
# 0         Horto flat with small garden
# 1     Ocean View Waikiki Marina w/prkg
# 2             Private Room in Bushwick
# 3          Apt Linda Vista Lagoa - Rio
# 4  New York City - Upper West Side Apt
#
#                                              summary  \
# 0  One bedroom + sofa-bed in quiet and bucolic ne...
# 1  A short distance from Honolulu's billion dolla...
# 2  Here exists a very cozy room for rent in a sha...
# 3  Quarto com vista para a Lagoa Rodrigo de Freit...
# 4
#
#                                                space  \
# 0  Lovely one bedroom + sofa-bed in the living ro...
# ...
